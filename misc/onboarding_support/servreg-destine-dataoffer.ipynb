# %% [markdown]
# # Service Registry – DestinE Platform Data Offer
#
# This section provides an overview of the datasets currently published in the DestinE Platform Service Registry.
# For each dataset, you will find a short description, the corresponding reference (when available), and its associated data hierarchy.
#
# This notebook is intended for Service Providers involved in the creation of their Service Data Offer as part of the Onboarding Integration process.
# We recommend running it to stay up to date with the full DestinE Platform data offering and to support the design of your own service.
#
# The data hierarchy in the Service Registry is organized as:
# ```
# Program/
# └── Program_Subset/
#     └── Collection/
#         └── Dataset
# ```
#
# The following code retrieves the parent–child relationships starting from the `Dataset` level and walking backward through the hierarchy.
#
# We kindly invite Service Providers willing to onboard a new service to use the current DestinE Platform data offer as their baseline for the Service Registry/Data Portfolio Survey.

# %%
import requests
r = requests.get("https://servreg.prod.desp.space:443/api/destine_platform_data_offer_view")

from IPython.display import JSON
product = r.json()
JSON(product)
